# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def plotdata(full_plt_data, full_errors_fractional, full_plt_xdist=None, ax=None):
    if full_plt_xdist is None:
        full_plt_xdist = range(0, len(full_plt_data), 1)
        xlab = 'index of gate-time data'
    else:
        xlab = 'downline distance (m)'
    
    full_errors_absolute = np.abs(full_plt_data * full_errors_fractional)
    
    if ax is None:
        fig, ax=plt.subplots(figsize=(15,4))
    h1 = ax.errorbar(full_plt_xdist, np.abs(full_plt_data), full_errors_absolute, c='r', capsize=2, lw=0.5, label='neg dbdt')
    h2 = ax.errorbar(full_plt_xdist, full_plt_data, full_errors_absolute, c='b', capsize=2, label='dbdt')
    ax.legend(handles=[h2, h1], fontsize=8)
    ax.set_xticks(np.linspace(full_plt_xdist[0], full_plt_xdist[-1], 23))
    ax.set_yscale('log')
    ax.set_xlabel(xlab)
    ax.set_ylabel('dB/dt [pV / (A * m^4)]')
    if ax is None:
        plt.show()

# %% [markdown]
# # define:
#  - gate-time ['plt_time'],
#  - x_distancearray ['full_plt_xdist'],
#  - dB/dt data ['full_plt_data'], and
#  - dB/dt assumed error level in fractional percent ['full_errors_fractional']

# %%
plt_time = 1.626e-05
full_plt_xdist = np.array([0., 15.93509657, 32.4220824, 43.60790347, 60.40632549, 77.23774114, 88.46487159, 105.02009674, 121.05712224, 136.50117584, 146.38055817, 160.70148594, 174.89873997, 189.4231524, 199.35145283, 214.45392839, 229.80011688, 240.09670972, 255.33303701, 270.30533139, 285.0275211, 294.77886845, 309.4952552, 324.25061649, 339.29278827, 349.57884785, 365.36913304, 381.33749709, 392.02811107, 407.80554961, 422.98990693, 437.78491485, 447.57517822, 462.01998044, 475.7693261, 488.87730092, 497.40613328, 510.01372498, 521.98070193, 529.50160023, 539.99729219, 549.93172771, 559.65328049, 566.20868397, 576.08331676, 586.09992751, 596.46350074, 603.48203906, 614.06012851, 624.5674885, 631.53711046, 642.10322727, 652.71518501, 663.41587134, 670.65275718, 681.8188637, 693.16015362, 704.27253934, 711.39040615, 721.53512075, 731.14167548, 737.31736965, 746.47463994, 755.81163452, 765.7144385, 772.79260163, 784.047523, 796.04448506, 808.62737946, 817.23639185, 830.00154765, 842.40325723, 850.50455027, 862.62365056, 874.93675144, 887.66003521, 896.45230378, 910.64398285, 926.26381464, 943.07064361, 954.55843463, 971.9385862, 989.46624847, 1001.0833294, 1017.94290434, 1034.42022481, 1050.42614876, 1060.76285456, 1075.57000285, 1089.58653946, 1102.60093174, 1110.76014868, 1122.35968449, 1133.78681062, 1141.44830027, 1153.24256475, 1165.69243212, 1178.80234167, 1187.79919076, 1201.36967516, 1214.70858792, 1227.39244953, 1235.38266317, 1246.58568392, 1256.97501562, 1263.54965044, 1273.14384099, 1282.67555926, 1292.39603345, 1299.05351677, 1309.31022078, 1319.73838341, 1330.29041855, 1337.36235995, 1348.14407024, 1359.17189253, 1366.64535163, 1378.01818957, 1389.5361517, 1401.2610319, 1409.26275119, 1421.6036377, 1434.31188897, 1447.22754082, 1455.95932781, 1469.27063515, 1482.8935572, 1492.33329215, 1507.48951567, 1523.84585935, 1541.1641592, 1552.98079717, 1570.46942533, 1587.40055352, 1603.81644685, 1614.40436247, 1629.79558685, 1644.6771523, 1654.
e+00, 5.29786088e+00, 3.97132623e+00, 4.04507466e+00, 2.00656295e+01, 7.93445287e+01, 3.00175242e+00, 2.83700515e+00, 1.38496026e+01, 3.30149121e+00, 2.49080137e+01, 2.54255190e+00, 1.08568165e+01, 1.14761571e+00, 1.23305674e+00, 9.90384985e-01, 3.63522576e+00, 3.79799188e+00, 9.98902122e-01, 9.37594978e-01, 5.61882790e-01, 5.26976256e-01, 4.30362392e-01, 4.52654037e-01, 5.82825514e-01, 6.11714178e-01, 3.99557415e-01, 3.39360480e-01, 3.87333861e-01, 7.42812194e-01, 5.54282770e-01, 4.16342898e-01, 4.30605616e-01, 4.16793470e-01, 4.09963057e-01, 5.08561460e-01, 3.88869496e-01, 3.21502355e-01, 3.37397756e-01, 2.12708067e-01, 2.99593951e-01, 3.18989704e-01, 3.35059693e-01, 3.65050812e-01, 2.80129927e-01, 3.39502148e-01, 2.44945643e-01, 2.33906247e-01, 3.02913502e-01, 2.16388739e-01, 1.46985342e-01, 2.00570625e-01, 2.82247919e-01, 1.71079661e-01, 2.04016362e-01, 3.32243660e-01, 2.46094415e-01, 3.07966488e-01, 2.76349937e-01, 3.63341292e-01, 3.60810167e-01, 5.15775051e-01, 4.71053994e-01, 4.20926908e-01, 7.04678758e-01, 9.25942894e-01, 1.34115941e+00, 6.82782319e-01, 7.16018280e-01, 1.12487787e+00, 8.88773618e-01, 7.35142052e-01, 8.14759519e-01, 5.76031984e-01, 9.71100414e-01, 1.97790770e+00, 1.28720245e+00, 1.28750785e+00, 1.60848062e+00, 4.66527992e-01, 4.61033239e-01, 6.70732262e-01, 6.05373325e-01, 9.64825416e-01, 1.21894672e+00, 7.53317732e-01, 5.94446560e-01, 2.97907633e-01, 5.24815546e-01, 3.96662588e-01, 5.36994920e-01, 5.07683468e-01, 4.49178382e-01, 4.09568230e-01, 2.84512339e-01, 3.61937451e-01, 3.68811947e-01, 5.04257828e-01, 3.52139752e-01, 4.54080585e-01, 4.69436588e-01, 3.50839285e-01, 4.16945012e-01, 5.71610253e-01, 4.26442690e-01, 7.21188356e-01, 7.39279128e-01, 4.63958471e-01, 5.88096632e-01, 9.09248123e-01, 6.43657472e-01, 3.84240276e-01, 6.65054029e-01, 5.56381253e-01, 5.89099563e-01, 1.19733606e+00, 1.47931788e+00, 1.58736574e+00, 9.37855612e-01, 2.38406154e+00, 2.82390563e+00, 1.07434041e+00, 1.31915401e+00, 1.97329024e+00])

# %%
full_errors_absolute = np.abs(full_plt_data * full_errors_fractional)

# %%
plotdata(full_plt_data, full_errors_fractional, full_plt_xdist)

# %%
# row_ind = range(15, 27, 1)
#row_ind = range(45, 52, 1)
#row_ind = range(48, 55, 1)
row_ind = range(45, 50, 1)

plt_xdist = full_plt_xdist[row_ind]
plt_data = full_plt_data[row_ind]
errors_fractional = full_errors_fractional[row_ind]

# %%
# Calculate absolute errors
errors_absolute = np.abs(plt_data * errors_fractional)

# Calculate mean absolute error
ave_err_abs = errors_absolute.mean()

# Calculate weights
weights = 1 / (errors_absolute*1.5)**2

# Calculate weighted average
average = np.sum(weights * plt_data) / np.sum(weights)

# Calc data std
STD = plt_data.std()
unweighted_SEM = plt_data.std() / np.sqrt(len(plt_data))

# Calculate standard error of the mean
weighted_SEM = np.sqrt(np.sum(weights) / 
               (np.sum(weights)**2))

# Balance error with STD of the data , standard error and average error
weighted_SEM_weight = 1
STD_weight = 1
mean_weight = 1

divby = weighted_SEM_weight + STD_weight + mean_weight

abs_bal_err = (weighted_SEM_weight*(weighted_SEM**2)/divby +
               STD_weight*         (         STD**2)/divby +
               mean_weight*        ( ave_err_abs**2)/divby  )**(1/2)


abs_bal_err = (weighted_SEM * STD * ave_err_abs)**(1/3)

# Calculate fractional percentage error of the average
average_fractional_error = abs_bal_err / average

# %%
print("time:", plt_time)
print("plt_xdist:", plt_xdist)
print("plt_data:", plt_data)
print("errors_fractional:", errors_fractional)
print("errors_absolute:", errors_absolute)
print("weights:", weights)
print("Weighted average:", average)
print("ave_err_abs:", ave_err_abs)
print("Standard deviation of the mean:", STD)
print("unweighted_SEM:", unweighted_SEM)
print("Standard error of the mean:", weighted_SEM)
print("ave_err _ Frac:", ave_err_abs / average)
print("Standard deviation of the mean _ Frac:", STD / average)
print("Unweighted SEM _ Frac:", unweighted_SEM / average)
print("Standard error of the mean _ Frac:", weighted_SEM / average)
print("Fractional error of the average:", average_fractional_error)
# Out:
# time: 1.626e-05
# plt_xdist: [586.09992751 596.46350074 603.48203906 614.06012851 624.5674885 ]
# plt_data: [ 230.649113  224.079306  355.882828  801.168026 1628.21397 ]
# errors_fractional: [0.44664667 0.30961019 0.23136602 0.13582644 0.0700838 ]
# errors_absolute: [103.0186578   69.37723606  82.33919492 108.81980402 114.1114263 ]
# weights: [4.18779783e-05 9.23386443e-05 6.55547626e-05 3.75319910e-05
#  3.41318017e-05]
# Weighted average: 513.2843162994374
# ave_err_abs: 95.53326381994228
# Standard deviation of the mean: 533.5733934560778
# unweighted_SEM: 238.6212757506063
# Standard error of the mean: 60.696959193758964
# ave_err _ Frac: 0.18612153301058693
# Standard deviation of the mean _ Frac: 1.0395279507133905
# Unweighted SEM _ Frac: 0.46489103246123836
# Standard error of the mean _ Frac: 0.11825212122466228
# Fractional error of the average: 0.2838881364851611

# %%
# plot
fig, ax = plt.subplots(figsize=(10,5))
for ii, datum in enumerate(plt_data):
    ax.errorbar(plt_xdist[ii], datum, errors_absolute[ii], capsize=3, label=f"{round(round(errors_absolute[ii]/datum, 4)*100,2)}%")

ax.errorbar(np.mean(plt_xdist)-3, average, ave_err_abs,    capsize=4, lw=3,   c='g', label=    f"averageErr {round(round(   ave_err_abs/average, 4)*100,2)}%")
ax.errorbar(np.mean(plt_xdist)-1, average, STD,            capsize=4, lw=3,   c='b', label=       f"STD_err {round(round(           STD/average, 4)*100,2)}%")
ax.errorbar(np.mean(plt_xdist)+1, average, unweighted_SEM, capsize=4, lw=3,   c='r', label=f"unweighted_SEM {round(round(unweighted_SEM/average, 4)*100,2)}%")
ax.errorbar(np.mean(plt_xdist)+3, average, weighted_SEM,   capsize=4, lw=3,   c='m', label=  f"weighted_SEM {round(round(  weighted_SEM/average, 4)*100,2)}%")
ax.errorbar(np.mean(plt_xdist)+5, average, abs_bal_err,    capsize=5, lw=3.5, c='k', label=f"\nBalanced_err {round(round(   abs_bal_err/average, 4)*100,2)}%\n")
# ax.errorbar(np.mean(t[:-1]), average, SEM, capsize=4, lw=3, c='k')    

ax.legend(fontsize=8)
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('x-distance, (m)')
ax.set_ylabel('data amplidude, pV/(A*m^4)')
plt.show()

# %%
# prep data into dataframes
data_df = pd.DataFrame(full_plt_data, columns=['dbdt'])
ferr_df = pd.DataFrame(full_errors_fractional, columns=['dbdt'])
aerr_df = (data_df * ferr_df).abs()

print(f"data_df:", data_df)
print(f"ferr_df:", ferr_df)
print(f"aerr_df:", aerr_df)
# Out:
# data_df:            dbdt
# 0    730.249506
# 1    884.644864
# 2    946.886817
# 3    976.895022
# 4    931.701360
# ..          ...
# 250   40.102477
# 251   33.749287
# 252   59.124491
# 253   50.413985
# 254   30.203104
#
# [255 rows x 1 columns]
# ferr_df:          dbdt
# 0    0.065662
# 1    0.069934
# 2    0.051266
# 3    0.051358
# 4    0.057796
# ..        ...
# 250  2.384062
# 251  2.823906
# 252  1.074340
# 253  1.319154
# 254  1.973290
#
# [255 rows x 1 columns]
# aerr_df:           dbdt
# 0    47.949289
# 1    61.866474
# 2    48.543475
# 3    50.171659
# 4    53.848174
# ..         ...
# 250  95.606774
# 251  95.304802
# 252  63.519829
# 253  66.503811
# 254  59.599490
#
# [255 rows x 1 columns]

# %%
# Calculate weights
weightingfactor = 0.25
weights = weightingfactor / (aerr_df)**2

# build weighted data
weighted_dbdt = data_df * weights

print(f"weights:", weights)
print(f"weighted_dbdt:", weighted_dbdt)
# Out:
# weights:          dbdt
# 0    0.000109
# 1    0.000065
# 2    0.000106
# 3    0.000099
# 4    0.000086
# ..        ...
# 250  0.000027
# 251  0.000028
# 252  0.000062
# 253  0.000057
# 254  0.000070
#
# [255 rows x 1 columns]
# weighted_dbdt:          dbdt
# 0    0.079405
# 1    0.057783
# 2    0.100456
# 3    0.097022
# 4    0.080329
# ..        ...
# 250  0.001097
# 251  0.000929
# 252  0.003663
# 253  0.002850
# 254  0.002126
#
# [255 rows x 1 columns]

# %%
window = 5
min_periods = np.ceil(window/2).astype(int)

ave_data_df = data_df * np.nan
ave_aerr_df = aerr_df * np.nan


# Calculate mean absolute error
ave_aerr_df = aerr_df.rolling(window=window, center=True, min_periods=min_periods).mean()

# Calculate STD error from data window
std_aerr_df = data_df.rolling(window=window, center=True, min_periods=min_periods).std()
unweighted_SEM = data_df.rolling(window=window, center=True, min_periods=min_periods).std() / np.sqrt(window)

# Calculate weighted average
ave_data_df = weighted_dbdt.rolling(window=window, center=True, min_periods=min_periods).sum() / \
                    weights.rolling(window=window, center=True, min_periods=min_periods).sum()


# Calculate standard error of the mean
weighted_SEM = (weights.rolling(window=window, center=True, min_periods=min_periods).sum() / 
               (weights.rolling(window=window, center=True, min_periods=min_periods).sum()**2))**(1/2)

# Balance error with STD of the data , standard error and average error
unweighted_SEM_weight = 1
weighted_SEM_weight = 1
STD_weight = 1
mean_weight = 1

divby = unweighted_SEM_weight + weighted_SEM_weight + STD_weight + mean_weight

abs_bal_err1 = (unweighted_SEM_weight *(unweighted_SEM**2)/divby +
                weighted_SEM_weight   *(  weighted_SEM**2)/divby +
                STD_weight            *(   std_aerr_df**2)/divby +
                mean_weight           *(   ave_err_abs**2)/divby  )**(1/2)


abs_bal_err2 = (unweighted_SEM * weighted_SEM * STD * ave_err_abs)**(1/divby)

# Calculate fractional percentage error of the average
average_fractional_error1 = abs_bal_err1 / average
average_fractional_error2 = abs_bal_err2 / average

# %%
import from_MAK.varianceaveraging as va

# %%
data_df.dbdt[0:3]
# Out:
# 0    730.249506
# 1    884.644864
# 2    946.886817
# Name: dbdt, dtype: float64

# %%
## Test MAK's SST method
verbose=False

ave_data = data_df.rolling(window=window, center=True, min_periods=min_periods).mean()
asst_std = aerr_df.copy()*np.nan
for sid in range(0, len(data_df.dbdt)):
    current_window = [int(sid-np.floor(window/2)), int(sid+np.floor(window/2)+1)]
    if current_window[0]<0:
        current_window[0] = 0
    if current_window[1]>len(data_df.dbdt):
        current_window[1] = len(data_df.dbdt)
    if verbose:
        print(f"\ncurrent_window = {current_window}")
        
    numsample = int(current_window[1] - current_window[0])
    if numsample >= min_periods:
        sample_weight = weights.dbdt.loc[current_window[0]: current_window[1] - 1].values
        # sample_data = weighted_dbdt.dbdt.loc[current_window[0]: current_window[1] - 1].values
        
        # sample_weight = np.ones(numsample)
        sample_data = data_df.dbdt.loc[current_window[0]: current_window[1] - 1].values
        
        sample_std = aerr_df.dbdt.loc[current_window[0]: current_window[1] - 1].values
        estimatedSST = np.sum(ave_data.dbdt.loc[current_window[0]: current_window[1] - 1].values / numsample)

        if verbose:
            print(f"sample_weight = {sample_weight}")
            print(f"sample_data = {sample_data}")
            print(f"sample_std = {sample_std}")
            print(f"estimatedSST = {estimatedSST}")
        
        var_est_SST = va.calcVarSST(sample_weight, sample_data, sample_std, estimatedSST)        
        std_est_SST = var_est_SST**0.5
        if verbose:
            print(f"std_est_SST = {std_est_SST}")
        asst_std.loc[sid, 'dbdt'] = std_est_SST

fesst_std = asst_std / ave_data
print(f"\nave_data = {ave_data}")
print(f"asst_std = {asst_std}")
print(f"fesst_std = {fesst_std}")
# Out:
# ave_data =            dbdt
# 0    853.927062
# 1    884.669052
# 2    894.075514
# 3    934.893278
# 4    939.961042
# ..          ...
# 250   49.420698
# 251   50.402115
# 252   42.718669
# 253   43.372717
# 254   46.580526
#
# [255 rows x 1 columns]
# asst_std =            dbdt
# 0    113.717671
# 1    113.438266
# 2    106.876188
# 3     67.706459
# 4     66.499919
# ..          ...
# 250   75.662846
# 251   74.415788
# 252   72.609001
# 253   69.102330
# 254   64.254083
#
# [255 rows x 1 columns]
# fesst_std =          dbdt
# 0    0.133170
# 1    0.128227
# 2    0.119538
# 3    0.072422
# 4    0.070748
# ..        ...
# 250  1.530995
# 251  1.476442
# 252  1.699702
# 253  1.593221
# 254  1.379419
#
# [255 rows x 1 columns]

# %%
print(f"ave_aerr_df:", ave_aerr_df)
print(f"abs_bal_err1:", abs_bal_err1)
print(f"abs_bal_err2:", abs_bal_err2)
print(f" = {asst_std}")
# Out:
# ave_aerr_df:           dbdt
# 0    52.786412
# 1    52.132724
# 2    52.475814
# 3    60.946395
# 4    63.968441
# ..         ...
# 250  78.204693
# 251  77.058237
# 252  76.106941
# 253  71.231983
# 254  63.207710
#
# [255 rows x 1 columns]
# abs_bal_err1:           dbdt
# 0    83.103741
# 1    81.010410
# 2    75.285315
# 3    57.095518
# 4    56.110263
# ..         ...
# 250  58.762389
# 251  58.400732
# 252  57.881315
# 253  59.104450
# 254  60.591796
#
# [255 rows x 1 columns]
# abs_bal_err2:            dbdt
# 0    111.019262
# 1    106.488189
# 2    100.729949
# 3     78.817855
# 4     73.580854
# ..          ...
# 250   68.195494
# 251   67.673558
# 252   64.646536
# 253   67.890052
# 254   70.433909
#
# [255 rows x 1 columns]
#  =            dbdt
# 0    113.717671
# 1    113.438266
# 2    106.876188
# 3     67.706459
# 4     66.499919
# ..          ...
# 250   75.662846
# 251   74.415788
# 252   72.609001
# 253   69.102330
# 254   64.254083
#
# [255 rows x 1 columns]

# %%
plot_dict = {}

plot_dict[0] = {'x_dat': full_plt_xdist, 'y_dat': ave_data.dbdt,    'y_err': asst_std.dbdt,       'title': 'MAK_SST'}
plot_dict[1] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': weighted_SEM.dbdt,   'title': 'Weighted SEM'}
plot_dict[2] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': unweighted_SEM.dbdt, 'title': 'Unweighted SEM'}
plot_dict[3] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': abs_bal_err1.dbdt,   'title': 'abs_bal_err1'}
plot_dict[4] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': abs_bal_err2.dbdt,   'title': 'abs_bal_err2'}
plot_dict[5] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': std_aerr_df.dbdt,    'title': 'std_aerr_df'}
plot_dict[6] = {'x_dat': full_plt_xdist, 'y_dat': ave_data_df.dbdt, 'y_err': ave_aerr_df.dbdt,    'title': 'ave_err_abs'}

# %%
numplot = len(plot_dict.keys())
fig, axs = plt.subplots(numplot, 1, figsize=(15, 15))

if full_plt_xdist is None:
        full_plt_xdist = range(0, len(full_plt_data), 1)
        xlab = 'index of gate-time data'
else:
    xlab = 'downline distance (m)'

def plot_ave_data(x_dat, y_dat, y_err, title, ax):
    h2 = ax.errorbar(x_dat, np.abs(y_dat), np.abs(y_err), c='r', capsize=2, lw=0.5, label='neg dbdt')
    h3 = ax.errorbar(x_dat, y_dat, np.abs(y_err), c='b', capsize=2, label='Ave_dbdt')
    ax.legend(handles=[h1, h3, h2], fontsize=8)
    ax.set_xticks(np.linspace(x_dat[0], x_dat[-1], 23))
    ax.set_yscale('log')
    ax.set_xlabel(xlab)
    ax.set_ylabel('dB/dt [pV / (A * m^4)]')
    ax.set_title(title)
    
for ii in range(0, numplot,1):
    ax = axs[ii]
    shift_fact = 1000
    h1 = ax.errorbar(full_plt_xdist, np.abs(full_plt_data) * shift_fact, np.abs(full_errors_fractional*full_plt_data) * shift_fact, c='grey', alpha=0.5, capsize=2, lw=0.5, label=f'shifted_raw dbdt (x{shift_fact})')
    plot_ave_data(plot_dict[ii]['x_dat'], plot_dict[ii]['y_dat'], plot_dict[ii]['y_err'], plot_dict[ii]['title'], ax)

plt.tight_layout()
plt.show()

# %%
weights.describe()

# %%
weights.sum()
